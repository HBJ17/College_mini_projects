# %%
#1
# #print all prime numbers between 1 to 100

# %%
#2
#recursive function to find the factorial of a number

# %%
#3
#count how many numbers are didvisible by 3 in range 1 to 100

# %%
#4
#check whether a number is prime

# %%
#5
#sum of all odd numbers between 1 to 100

# %%
#6
#fibanacci series through recursion

# %%
#7
#multiplication table

# %%
#8
#palindrome check without string method

# %%
#9
#numbers between 1 to 100 that are divisble by 3 and 7

# %%
#10
#GCD of 2 numbers

# %%
#11
#numbers between 1 to 100 thatare divisible by 2 and 5

# %%
#12
#sum and average of elements in a list

# %%
#13
#number of digits in a input number

# %%
#14
#sum of digits using recursion

# %%
#15
#cubes of all numbers between 1 to 10

# %%
#16
#number of even digits in number

# %%
#17
#numbers between 1 to 100 that are divisible by 7 and not by 5

# %%
#18
#factorial using recursion

# %%
#19
#sum of all even input numbers untill the input is 0

# %%
#20
#smallest element in a list

# %%
#21
#projects squares between 1 to 100

# %%
#22
#GCD recursive

# %%
#23
#armstrog numbers between 1 to 100

# %%
#24
#returns the count of constants and vowels in a string

# %%
#25
#all numbers from 1 to 50 that are multilples of 3 and 5

# %%
#26
#write a recursive function to find the sum of digits of a number

# %%
#27
#all perfect numbers between 1 to 1000

# %%
#28
#accepts a sentence and retur in a reverse order

# %%
#29
#1 to 100 ,numbers that divisble by 4 and 6

# %%
#30
#recursive factorial

# %%
#31
#1 to 100 , divisible by 5 and not by 10

# %%
#32
#armstrong number check

# %%
#33
#1 to 100 , all numbers that divisible by both 3 and 7

# %%
#34
#fibonacci through recursion

# %%
#35
#fibonacci of n terms using a for loop

# %%
#36
#return sum of even numbers between 1 to n

# %%
#37
#count of how many numbers from 1 to 200 that are ven and is multiples of 9

# %%
#38
#recursive function to find sum of digits of a number

# %%
#39
#write a program to display the factorial of a number using a for loop

# %%
#40
#write a fucntion that converts celcius to farenheit and vice versa based on user choice
