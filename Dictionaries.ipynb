# %%
student = {
    "name": "Arun",
    "age": 20,
    "course": "CSE"
}

print(student)
print(len(student))
print(type(student))


data = {
    1: "one",
    "two": 2,
    True: "yes"
}

print(student["name"])
print(student.get("age"))
print(student.get("marks", "Not Available"))

student["age"] = 21
student["marks"] = 95

print(student)

print(student.keys())
print(student.values())
print(student.items())
# Out:
# {'name': 'Arun', 'age': 20, 'course': 'CSE'}
# 3
# <class 'dict'>
# Arun
# 20
# Not Available
# {'name': 'Arun', 'age': 21, 'course': 'CSE', 'marks': 95}
# dict_keys(['name', 'age', 'course', 'marks'])
# dict_values(['Arun', 21, 'CSE', 95])
# dict_items([('name', 'Arun'), ('age', 21), ('course', 'CSE'), ('marks', 95)])

# %%
for key in student:
    print(key)

for value in student.values():
    print(value)

for key, value in student.items():
    print(key, ":", value)

# %%
d = {
    "j" : {"a" : 3 , "b" : 4},
    "g" : {"c" : 5 , "d" : 6}

}

print(d["j"])
print(d["j"]["a"])

print(d)
# Out:
# {'a': 3, 'b': 4}
# 3
# {'j': {'a': 3, 'b': 4}, 'g': {'c': 5, 'd': 6}}
